# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton
# %matplotlib inline

# %% [markdown]
# ### Problem 1

# %%
def EmbeddingAlg(param_list, guess, F):
    X = []
    for param in param_list:
        try:
            # Solve for x_value making F(x_value, param) = 0.
            x_value = newton(F, guess, fprime=None, args=(param,), tol=1E-7,maxiter=50)
            # Record the solution and update guess for the next iteration.
            X.append(x_value)
            guess = x_value
        except RuntimeError:
            # If Newton's method fails, return a truncated list of parameters
            # with the corresponding x values.
            return param_list[:len(X)], X
    # Return the list of parameters and the corresponding x values.
    return param_list, X

def F(x, lmbda):
    return lmbda*x - x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200), -np.sqrt(5), F)
# The middle curve
C3, X3 = EmbeddingAlg(np.linspace(5, -5, 200), 0, F)

plt.plot(C1,X1)
plt.plot(C2,X2)
plt.plot(C3,X3)
plt.show()

# %% [markdown]
# ### Problem 2

# %%
def F(x, lmbda):
    return -1 + lmbda*x - x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200), -np.sqrt(5), F)
# The middle curve
C3, X3 = EmbeddingAlg(np.linspace(5, -5, 200), 0, F)

plt.plot(C1,X1)
plt.plot(C2,X2)
plt.plot(C3,X3)
plt.title("Eta = -1")
plt.show()

# %%
def F(x, lmbda):
    return -.2 + lmbda*x - x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200), -np.sqrt(5), F)
# The middle curve
C3, X3 = EmbeddingAlg(np.linspace(5, -5, 200), 0, F)

plt.plot(C1,X1)
plt.plot(C2,X2)
plt.plot(C3,X3)
plt.title("Eta = -0.2")
plt.show()

# %%
def F(x, lmbda):
    return .2 + lmbda*x - x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200), -np.sqrt(5), F)
# The middle curve
C3, X3 = EmbeddingAlg(np.linspace(5, -5, 200), 0, F)

plt.plot(C1,X1)
plt.plot(C2,X2)
plt.plot(C3,X3)
plt.title("Eta = 0.2")
plt.show()

# %%
def F(x, lmbda):
    return 1 + lmbda*x - x**3

# Top curve shown in the bifurcation diagram
C1, X1 = EmbeddingAlg(np.linspace(5, -5, 200), np.sqrt(5), F)
# The bottom curve
C2, X2 = EmbeddingAlg(np.linspace(5, -5, 200), -np.sqrt(5), F)
# The middle curve
C3, X3 = EmbeddingAlg(np.linspace(5, -5, 200), 0, F)

plt.plot(C1,X1)
plt.plot(C2,X2)
plt.plot(C3,X3)
plt.title("Eta = 1")
plt.show()

# %% [markdown]
# ### Problem 3

# %%
r = 0.56

def F(x, k) :
    return r*x*(1-x/k) - x**2/(1+x**2)

C1, X1 = EmbeddingAlg(np.linspace(14, 0, 200), 8, F)
C2, X2 = EmbeddingAlg(np.linspace(6.3, 2, 200), 4, F)
C3, X3 = EmbeddingAlg(np.linspace(9.5, 6.4, 200), 4, F)
C4, X4 = EmbeddingAlg(np.linspace(9.15, 6.35, 200), 4, F)

plt.plot(C1, X1, 'k')
plt.plot(C2, X2, 'k')
plt.plot(C3, X3, '--k')
plt.plot(C4, X4, 'k')
plt.axis([0,15,-5,15])
plt.show()
